# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

file_path = '/content/drive/MyDrive/Ewhathon_final.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#    장애유형    학수번호  분반                  교과목명  개설학과/전공         교과영역 교과목 구분  \
# 0    청각   10072   2               서양미술의이해     미술사학  핵심교양(예술과표현)     교양
# 1    청각   11089   1       여행과지리:글로벌화의지역탐색    사회과교육  핵심교양(인간과사회)     교양
# 2    청각   38640   1               북한과인권문제      북한학           전선     전선
# 3    청각   11148   1           문학으로보는사랑의역사  이화인문과학원  핵심교양(문학과언어)     교양
# 4    청각   38010   2                 UI디자인  융합콘텐츠학과           전선     전선
# 5    청각   10023   4                기독교와세계    기독교학과        이화진선미     교양
# 6    청각  B34011   1                파생금융상품     경영학부           전선     전선
# 7    청각   36500   1               디지털논리설계    컴퓨터공학           전선     전선
# 8    청각   35339   4             객체지향프로그래밍    컴퓨터공학           전기     전기
# 9    청각   20479   2                  이산수학    컴퓨터공학           전기     전기
# 10   시각   ED114   1        교육실습II(학교현장실습)     교육학과           전기     전기
# 11   시각   34947   1              교육철학및교육사     교육학과           전기     전기
# 12   시각   34800   5                   대위Ⅰ      작곡과           전기     전기
# 13   시각   20007   2                  교육심리     교육학과           전기     전기
# 14   시각   11054   1  연어프로젝트: 한국여성나의뿌리를찾아서    국어국문학  핵심교양(역사와철학)     교양
# 15  뇌병변   20477   1                  운영체제    컴퓨터공학           전필     전필
# 16  뇌병변   30226   1             오토마타및형식언어    컴퓨터공학           전선     전선
# 17  뇌병변   20497   3               컴퓨터알고리즘    컴퓨터공학           전선     전선
# 18  뇌병변   20471   1                데이터베이스    컴퓨터공학           전선     전선
# 19  뇌병변   20407   3                미분적분학Ⅰ      수학과           전기     전기
# 20  뇌병변   34743   1                정보통신공학    컴퓨터공학           전필     전필
# 21  자폐성   11233   1         음악테크놀로지와프로그래밍      작곡과    컴퓨팅과수리적사고     교양
# 22  자폐성   32833   1                   일본사      사학과           전선     전선
# 23  자폐성   36919   1               중급일본어작문   일본언어문화           전선     전선
# 24  뇌병변   20413   2               일반생물학 Ⅰ     생명과학           전기     전기
#
#                교수명   정원   시간   학점          요일/교시  교실   지원종류 원격강의 이동지원 교생실습지원  \
# 0              전동호  200  3.0  3.0              -   -   노트필기    O    X      X
# 1              이화용  200  3.0  3.0          화 4~5   학   노트필기    X    X      X
# 2              박민주  100  3.0  3.0   화 4~4\n금 5~5   포  노트북속타    X    X      X
# 3              김경미   80  3.0  3.0   월 5~5\n수 4~4   학  노트북속타    X    X      X
# 4              정승은   20  3.0  3.0          화 6~7  정보  노트북속타    X    X      X
# 5              이주아  100  3.0  3.0   수 3~3\n금 4~4   캠  노트북속타    X    X      X
# 6              지홍민   60  3.0  3.0          월 8~9   경  노트북속타    X    X      X
# 7              박상수   50  3.0  3.0   월 3~3\n수 2~2  공A   노트필기    X    X      X
# 8              안영아   35  3.0  3.0   화 3~3\n목 2~2  공A   노트필기    X    X      X
# 9              홍성원   50  3.0  3.0   월 4~4\n목 5~5  공A   노트필기    X    X      X
# 10          서혁외 1명   30  2.0  2.0              -   -     기타    X    X      O
# 11             이은주   30  2.0  2.0          화 2~3   교     기타    X    X      X
# 12             김주혜   30  2.0  2.0          목 5~6   음   노트필기    X    O      X
# 13             이승은   30  2.0  2.0          수 4~5   학   노트필기    X    X      X
# 14             김승우   80  3.0  3.0   월 2~2\n목 3~3   학   노트필기    X    X      X
# 15             권진욱  110  3.0  3.0   월 6~6\n수 5~5  공A   노트필기    X    X      X
# 16              김명   70  3.0  3.0   수 6~6\n금 4~4  공B   노트필기    X    X      X
# 17             박숙영  100  3.0  3.0   화 5~5\n목 6~6  공B   노트필기    X    X      X
# 18             이민수   70  3.0  3.0   월 5~5\n수 4~4  공B   노트필기    X    X      X
# 19             안수형   60  3.0  3.0   월 5~5\n수 4~4   포   노트필기    X    X      X
# 20             이형준   70  3.0  3.0   월 3~3\n수 2~2  공B   노트필기    X    X      X
# 21             전현석   90  3.0  3.0   수 3~3\n금 4~4   음   노트필기    X    X      X
# 22             함예재   64  3.0  3.0  화 6~6\n목 4~4    학   노트필기    X    X      X
# 23  Yoshida, Reiko   30  3.0  3.0   화 4~4\n금 5~5   학   노트필기    X    X      X
# 24        정우진 외 1명   50  3.0  3.0   화 4~4\n금 5~5   포   노트필기    X    X      X
#
#    수업참여지원 알림사항지원 결과
# 0       X      X  O
# 1       X      X  O
# 2       X      X  X
# 3       X      X  X
# 4       X      X  X
# 5       X      X  O
# 6       X      X  O
# 7       X      X  X
# 8       X      X  O
# 9       X      X  X
# 10      X      X  O
# 11      O      X  O
# 12      X      X  X
# 13      X      X  O
# 14      X      X  X
# 15      X      X  O
# 16      X      X  O
# 17      X      X  X
# 18      X      X  X
# 19      X      X  X
# 20      X      X  O
# 21      X      O  O
# 22      X      O  O
# 23      X      O  X
# 24      X      X  X

# %%
df = df.rename(columns={'장애유형': 'disType'})
df = df.rename(columns={'학수번호': 'haksuNum'})
df = df.rename(columns={'분반': 'classNum'})
df = df.rename(columns={'교과목명': 'className'})
df = df.rename(columns={'개설학과/전공': 'classDept'})
df = df.rename(columns={'교과영역': 'subjectArea'})
df = df.rename(columns={'교과목 구분': 'subjectArea2'})
df = df.rename(columns={'교수명': 'profName'})
df = df.rename(columns={'정원': 'studentNum'})
df = df.rename(columns={'시간': 'classTime'})
df = df.rename(columns={'학점': 'Credit'})
df = df.rename(columns={'요일/교시': 'classDate'})
df = df.rename(columns={'교실': 'classLocation'})
df = df.rename(columns={'지원종류': 'helpType'})
df = df.rename(columns={'원격강의': 'classOnline'})
df = df.rename(columns={'이동지원': 'helpMove'})
df = df.rename(columns={'교생실습지원': 'helpTeach'})
df = df.rename(columns={'수업참여지원': 'helpParticipate'})
df = df.rename(columns={'알림사항지원': 'helpAlert'})
df = df.rename(columns={'결과': 'result'})

# %%
df
# Out:
#    disType haksuNum  classNum             className classDept  subjectArea  \
# 0       청각    10072         2               서양미술의이해      미술사학  핵심교양(예술과표현)
# 1       청각    11089         1       여행과지리:글로벌화의지역탐색     사회과교육  핵심교양(인간과사회)
# 2       청각    38640         1               북한과인권문제       북한학           전선
# 3       청각    11148         1           문학으로보는사랑의역사   이화인문과학원  핵심교양(문학과언어)
# 4       청각    38010         2                 UI디자인   융합콘텐츠학과           전선
# 5       청각    10023         4                기독교와세계     기독교학과        이화진선미
# 6       청각   B34011         1                파생금융상품      경영학부           전선
# 7       청각    36500         1               디지털논리설계     컴퓨터공학           전선
# 8       청각    35339         4             객체지향프로그래밍     컴퓨터공학           전기
# 9       청각    20479         2                  이산수학     컴퓨터공학           전기
# 10      시각    ED114         1        교육실습II(학교현장실습)      교육학과           전기
# 11      시각    34947         1              교육철학및교육사      교육학과           전기
# 12      시각    34800         5                   대위Ⅰ       작곡과           전기
# 13      시각    20007         2                  교육심리      교육학과           전기
# 14      시각    11054         1  연어프로젝트: 한국여성나의뿌리를찾아서     국어국문학  핵심교양(역사와철학)
# 15     뇌병변    20477         1                  운영체제     컴퓨터공학           전필
# 16     뇌병변    30226         1             오토마타및형식언어     컴퓨터공학           전선
# 17     뇌병변    20497         3               컴퓨터알고리즘     컴퓨터공학           전선
# 18     뇌병변    20471         1                데이터베이스     컴퓨터공학           전선
# 19     뇌병변    20407         3                미분적분학Ⅰ       수학과           전기
# 20     뇌병변    34743         1                정보통신공학     컴퓨터공학           전필
# 21     자폐성    11233         1         음악테크놀로지와프로그래밍       작곡과    컴퓨팅과수리적사고
# 22     자폐성    32833         1                   일본사       사학과           전선
# 23     자폐성    36919         1               중급일본어작문    일본언어문화           전선
# 24     뇌병변    20413         2               일반생물학 Ⅰ      생명과학           전기
#
#    subjectArea2        profName  studentNum  classTime  Credit      classDate  \
# 0            교양             전동호         200        3.0     3.0              -
# 1            교양             이화용         200        3.0     3.0          화 4~5
# 2            전선             박민주         100        3.0     3.0   화 4~4\n금 5~5
# 3            교양             김경미          80        3.0     3.0   월 5~5\n수 4~4
# 4            전선             정승은          20        3.0     3.0          화 6~7
# 5            교양             이주아         100        3.0     3.0   수 3~3\n금 4~4
# 6            전선             지홍민          60        3.0     3.0          월 8~9
# 7            전선             박상수          50        3.0     3.0   월 3~3\n수 2~2
# 8            전기             안영아          35        3.0     3.0   화 3~3\n목 2~2
# 9            전기             홍성원          50        3.0     3.0   월 4~4\n목 5~5
# 10           전기          서혁외 1명          30        2.0     2.0              -
# 11           전기             이은주          30        2.0     2.0          화 2~3
# 12           전기             김주혜          30        2.0     2.0          목 5~6
# 13           전기             이승은          30        2.0     2.0          수 4~5
# 14           교양             김승우          80        3.0     3.0   월 2~2\n목 3~3
# 15           전필             권진욱         110        3.0     3.0   월 6~6\n수 5~5
# 16           전선              김명          70        3.0     3.0   수 6~6\n금 4~4
# 17           전선             박숙영         100        3.0     3.0   화 5~5\n목 6~6
# 18           전선             이민수          70        3.0     3.0   월 5~5\n수 4~4
# 19           전기             안수형          60        3.0     3.0   월 5~5\n수 4~4
# 20           전필             이형준          70        3.0     3.0   월 3~3\n수 2~2
# 21           교양             전현석          90        3.0     3.0   수 3~3\n금 4~4
# 22           전선             함예재          64        3.0     3.0  화 6~6\n목 4~4
# 23           전선  Yoshida, Reiko          30        3.0     3.0   화 4~4\n금 5~5
# 24           전기        정우진 외 1명          50        3.0     3.0   화 4~4\n금 5~5
#
#    classLocation helpType classOnline helpMove helpTeach helpParticipate  \
# 0              -     노트필기           O        X         X               X
# 1              학     노트필기           X        X         X               X
# 2              포    노트북속타           X        X         X               X
# 3              학    노트북속타           X        X         X               X
# 4             정보    노트북속타           X        X         X               X
# 5              캠    노트북속타           X        X         X               X
# 6              경    노트북속타           X        X         X               X
# 7             공A     노트필기           X        X         X               X
# 8             공A     노트필기           X        X         X               X
# 9             공A     노트필기           X        X         X               X
# 10             -       기타           X        X         O               X
# 11             교       기타           X        X         X               O
# 12             음     노트필기           X        O         X               X
# 13             학     노트필기           X        X         X               X
# 14             학     노트필기           X        X         X               X
# 15            공A     노트필기           X        X         X               X
# 16            공B     노트필기           X        X         X               X
# 17            공B     노트필기           X        X         X               X
# 18            공B     노트필기           X        X         X               X
# 19             포     노트필기           X        X         X               X
# 20            공B     노트필기           X        X         X               X
# 21             음     노트필기           X        X         X               X
# 22             학     노트필기           X        X         X               X
# 23             학     노트필기           X        X         X               X
# 24             포     노트필기           X        X         X               X
#
#    helpAlert result
# 0          X      O
# 1          X      O
# 2          X      X
# 3          X      X
# 4          X      X
# 5          X      O
# 6          X      O
# 7          X      X
# 8          X      O
# 9          X      X
# 10         X      O
# 11         X      O
# 12         X      X
# 13         X      O
# 14         X      X
# 15         X      O
# 16         X      O
# 17         X      X
# 18         X      X
# 19         X      X
# 20         X      O
# 21         O      O
# 22         O      O
# 23         O      X
# 24         X      X

# %%
from sklearn.preprocessing import OrdinalEncoder

def ordinal_encoder():
   return OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

ordinal_encoder_disType = ordinal_encoder()
ordinal_encoder_haksuNum = ordinal_encoder()
ordinal_encoder_className = ordinal_encoder()
ordinal_encoder_classDept = ordinal_encoder()
ordinal_encoder_subjectArea = ordinal_encoder()
ordinal_encoder_subjectArea2 = ordinal_encoder()
ordinal_encoder_profName = ordinal_encoder()
ordinal_encoder_studentNum = ordinal_encoder()
ordinal_encoder_classTime = ordinal_encoder()
ordinal_encoder_Credit = ordinal_encoder()
ordinal_encoder_classDate = ordinal_encoder()
ordinal_encoder_classLocation = ordinal_encoder()
ordinal_encoder_helpType = ordinal_encoder()

df['disType'] = ordinal_encoder_disType.fit_transform(df[['disType']])
df['haksuNum'] = ordinal_encoder_haksuNum.fit_transform(df[['haksuNum']])
df['className'] = ordinal_encoder_className.fit_transform(df[['className']])
df['classDept'] = ordinal_encoder_classDept.fit_transform(df[['classDept']])
df['subjectArea'] = ordinal_encoder_subjectArea.fit_transform(df[['subjectArea']])
df['subjectArea2'] = ordinal_encoder_subjectArea2.fit_transform(df[['subjectArea2']])
df['profName'] = ordinal_encoder_profName.fit_transform(df[['profName']])
df['studentNum'] = ordinal_encoder_studentNum.fit_transform(df[['studentNum']])
df['classTime'] = ordinal_encoder_classTime.fit_transform(df[['classTime']])
df['Credit'] = ordinal_encoder_Credit.fit_transform(df[['Credit']])
df['classDate'] = ordinal_encoder_classDate.fit_transform(df[['classDate']])
df['classLocation'] = ordinal_encoder_classLocation.fit_transform(df[['classLocation']])
df['helpType'] = ordinal_encoder_helpType.fit_transform(df[['helpType']])

# %%
mapping_disType = dict(zip(ordinal_encoder_disType.categories_[0], ordinal_encoder_disType.fit_transform(ordinal_encoder_disType.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_haksuNum = dict(zip(ordinal_encoder_haksuNum.categories_[0], ordinal_encoder_haksuNum.fit_transform(ordinal_encoder_disType.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_className = dict(zip(ordinal_encoder_className.categories_[0], ordinal_encoder_className.fit_transform(ordinal_encoder_className.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_classDept = dict(zip(ordinal_encoder_classDept.categories_[0], ordinal_encoder_classDept.fit_transform(ordinal_encoder_classDept.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_subjectArea = dict(zip(ordinal_encoder_subjectArea.categories_[0], ordinal_encoder_subjectArea.fit_transform(ordinal_encoder_subjectArea.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_subjectArea2 = dict(zip(ordinal_encoder_subjectArea2.categories_[0], ordinal_encoder_subjectArea2.fit_transform(ordinal_encoder_subjectArea2.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_profName = dict(zip(ordinal_encoder_profName.categories_[0], ordinal_encoder_profName.fit_transform(ordinal_encoder_profName.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_studentNum = dict(zip(ordinal_encoder_studentNum.categories_[0], ordinal_encoder_studentNum.fit_transform(ordinal_encoder_studentNum.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_classTime = dict(zip(ordinal_encoder_classTime.categories_[0], ordinal_encoder_classTime.fit_transform(ordinal_encoder_classTime.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_Credit = dict(zip(ordinal_encoder_Credit.categories_[0], ordinal_encoder_Credit.fit_transform(ordinal_encoder_Credit.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_classDate = dict(zip(ordinal_encoder_classDate.categories_[0], ordinal_encoder_classDate.fit_transform(ordinal_encoder_classDate.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_classLocation = dict(zip(ordinal_encoder_classLocation.categories_[0], ordinal_encoder_classLocation.fit_transform(ordinal_encoder_classLocation.categories_[0].reshape(-1, 1)).flatten().tolist()))
mapping_helpType = dict(zip(ordinal_encoder_helpType.categories_[0], ordinal_encoder_helpType.fit_transform(ordinal_encoder_helpType.categories_[0].reshape(-1, 1)).flatten().tolist()))

# %%
print("Mapping for 'disType:", mapping_disType)
print("Mapping for 'haksuNum':", mapping_haksuNum)
print("Mapping for 'className':", mapping_className)
print("Mapping for 'classDept':", mapping_classDept)
print("Mapping for 'subjectArea':", mapping_subjectArea)
print("Mapping for 'subjectArea2':", mapping_subjectArea2)
print("Mapping for 'profName':", mapping_profName)
print("Mapping for 'studentNum':", mapping_studentNum)
print("Mapping for 'classTime':", mapping_classTime)
print("Mapping for 'Credit':", mapping_Credit)
print("Mapping for 'classDate':", mapping_classDate)
print("Mapping for 'classLocation':", mapping_classLocation)
print("Mapping for 'helpType':", mapping_helpType)

replacement_map = {'O': 1, 'X': 0}

df['classOnline'] = df['classOnline'].replace(replacement_map)
df['helpMove'] = df['helpMove'].replace(replacement_map)
df['helpTeach'] = df['helpTeach'].replace(replacement_map)
df['helpParticipate'] = df['helpParticipate'].replace(replacement_map)
df['helpAlert'] = df['helpAlert'].replace(replacement_map)
df['result'] = df['result'].replace(replacement_map)
# Out:
# Mapping for 'disType: {'뇌병변': 0.0, '시각': 1.0, '자폐성': 2.0, '청각': 3.0}
# Mapping for 'haksuNum': {'10023': 0.0, '10072': 1.0, '11054': 2.0, '11089': 3.0}
# Mapping for 'className': {'UI디자인': 0.0, '객체지향프로그래밍': 1.0, '교육실습II(학교현장실습)': 2.0, '교육심리': 3.0, '교육철학및교육사': 4.0, '기독교와세계': 5.0, '대위Ⅰ': 6.0, '데이터베이스': 7.0, '디지털논리설계': 8.0, '문학으로보는사랑의역사': 9.0, '미분적분학Ⅰ': 10.0, '북한과인권문제': 11.0, '서양미술의이해': 12.0, '여행과지리:글로벌화의지역탐색': 13.0, '연어프로젝트: 한국여성나의뿌리를찾아서': 14.0, '오토마타및형식언어': 15.0, '운영체제': 16.0, '음악테크놀로지와프로그래밍': 17.0, '이산수학': 18.0, '일반생물학 Ⅰ': 19.0, '일본사': 20.0, '정보통신공학': 21.0, '중급일본어작문': 22.0, '컴퓨터알고리즘': 23.0, '파생금융상품': 24.0}
# Mapping for 'classDept': {'경영학부': 0.0, '교육학과': 1.0, '국어국문학': 2.0, '기독교학과': 3.0, '미술사학': 4.0, '북한학': 5.0, '사학과': 6.0, '사회과교육': 7.0, '생명과학': 8.0, '수학과': 9.0, '융합콘텐츠학과': 10.0, '이화인문과학원': 11.0, '일본언어문화': 12.0, '작곡과': 13.0, '컴퓨터공학': 14.0}
# Mapping for 'subjectArea': {'이화진선미': 0.0, '전기': 1.0, '전선': 2.0, '전필': 3.0, '컴퓨팅과수리적사고': 4.0, '핵심교양(문학과언어)': 5.0, '핵심교양(역사와철학)': 6.0, '핵심교양(예술과표현)': 7.0, '핵심교양(인간과사회)': 8.0}
# Mapping for 'subjectArea2': {'교양': 0.0, '전기': 1.0, '전선': 2.0, '전필': 3.0}
# Mapping for 'profName': {'Yoshida, Reiko': 0.0, '권진욱': 1.0, '김경미': 2.0, '김명': 3.0, '김승우': 4.0, '김주혜': 5.0, '박민주': 6.0, '박상수': 7.0, '박숙영': 8.0, '서혁외 1명': 9.0, '안수형': 10.0, '안영아': 11.0, '이민수': 12.0, '이승은': 13.0, '이은주': 14.0, '이주아': 15.0, '이형준': 16.0, '이화용': 17.0, '전동호': 18.0, '전현석': 19.0, '정승은': 20.0, '정우진 외 1명': 21.0, '지홍민': 22.0, '함예재': 23.0, '홍성원': 24.0}
# Mapping for 'studentNum': {20: 0.0, 30: 1.0, 35: 2.0, 50: 3.0, 60: 4.0, 64: 5.0, 70: 6.0, 80: 7.0, 90: 8.0, 100: 9.0, 110: 10.0, 200: 11.0}
# Mapping for 'classTime': {2.0: 0.0, 3.0: 1.0}
# Mapping for 'Credit': {2.0: 0.0, 3.0: 1.0}
# Mapping for 'classDate': {'-': 0.0, '목 5~6': 1.0, '수 3~3\n금 4~4': 2.0, '수 4~5': 3.0, '수 6~6\n금 4~4': 4.0, '월 2~2\n목 3~3': 5.0, '월 3~3\n수 2~2': 6.0, '월 4~4\n목 5~5': 7.0, '월 5~5\n수 4~4': 8.0, '월 6~6\n수 5~5': 9.0, '월 8~9': 10.0, '화 2~3': 11.0, '화 3~3\n목 2~2': 12.0, '화 4~4\n금 5~5': 13.0, '화 4~5': 14.0, '화 5~5\n목 6~6': 15.0, '화 6~6\n목 4~4 ': 16.0, '화 6~7': 17.0}
# Mapping for 'classLocation': {'-': 0.0, '경': 1.0, '공A': 2.0, '공B': 3.0, '교': 4.0, '음': 5.0, '정보': 6.0, '캠': 7.0, '포': 8.0, '학': 9.0}
# Mapping for 'helpType': {'기타': 0.0, '노트북속타': 1.0, '노트필기': 2.0}

# %%
df
# Out:
#     disType  haksuNum  classNum  className  classDept  subjectArea  \
# 0       3.0       1.0         2       12.0        4.0          7.0
# 1       3.0       3.0         1       13.0        7.0          8.0
# 2       3.0      22.0         1       11.0        5.0          2.0
# 3       3.0       4.0         1        9.0       11.0          5.0
# 4       3.0      21.0         2        0.0       10.0          2.0
# 5       3.0       0.0         4        5.0        3.0          0.0
# 6       3.0      23.0         1       24.0        0.0          2.0
# 7       3.0      19.0         1        8.0       14.0          2.0
# 8       3.0      18.0         4        1.0       14.0          1.0
# 9       3.0      11.0         2       18.0       14.0          1.0
# 10      1.0      24.0         1        2.0        1.0          1.0
# 11      1.0      17.0         1        4.0        1.0          1.0
# 12      1.0      16.0         5        6.0       13.0          1.0
# 13      1.0       6.0         2        3.0        1.0          1.0
# 14      1.0       2.0         1       14.0        2.0          6.0
# 15      0.0      10.0         1       16.0       14.0          3.0
# 16      0.0      13.0         1       15.0       14.0          2.0
# 17      0.0      12.0         3       23.0       14.0          2.0
# 18      0.0       9.0         1        7.0       14.0          2.0
# 19      0.0       7.0         3       10.0        9.0          1.0
# 20      0.0      15.0         1       21.0       14.0          3.0
# 21      2.0       5.0         1       17.0       13.0          4.0
# 22      2.0      14.0         1       20.0        6.0          2.0
# 23      2.0      20.0         1       22.0       12.0          2.0
# 24      0.0       8.0         2       19.0        8.0          1.0
#
#     subjectArea2  profName  studentNum  classTime  Credit  classDate  \
# 0            0.0      18.0        11.0        1.0     1.0        0.0
# 1            0.0      17.0        11.0        1.0     1.0       14.0
# 2            2.0       6.0         9.0        1.0     1.0       13.0
# 3            0.0       2.0         7.0        1.0     1.0        8.0
# 4            2.0      20.0         0.0        1.0     1.0       17.0
# 5            0.0      15.0         9.0        1.0     1.0        2.0
# 6            2.0      22.0         4.0        1.0     1.0       10.0
# 7            2.0       7.0         3.0        1.0     1.0        6.0
# 8            1.0      11.0         2.0        1.0     1.0       12.0
# 9            1.0      24.0         3.0        1.0     1.0        7.0
# 10           1.0       9.0         1.0        0.0     0.0        0.0
# 11           1.0      14.0         1.0        0.0     0.0       11.0
# 12           1.0       5.0         1.0        0.0     0.0        1.0
# 13           1.0      13.0         1.0        0.0     0.0        3.0
# 14           0.0       4.0         7.0        1.0     1.0        5.0
# 15           3.0       1.0        10.0        1.0     1.0        9.0
# 16           2.0       3.0         6.0        1.0     1.0        4.0
# 17           2.0       8.0         9.0        1.0     1.0       15.0
# 18           2.0      12.0         6.0        1.0     1.0        8.0
# 19           1.0      10.0         4.0        1.0     1.0        8.0
# 20           3.0      16.0         6.0        1.0     1.0        6.0
# 21           0.0      19.0         8.0        1.0     1.0        2.0
# 22           2.0      23.0         5.0        1.0     1.0       16.0
# 23           2.0       0.0         1.0        1.0     1.0       13.0
# 24           1.0      21.0         3.0        1.0     1.0       13.0
#
#     classLocation  helpType  classOnline  helpMove  helpTeach  \
# 0             0.0       2.0            1         0          0
# 1             9.0       2.0            0         0          0
# 2             8.0       1.0            0         0          0
# 3             9.0       1.0            0         0          0
# 4             6.0       1.0            0         0          0
# 5             7.0       1.0            0         0          0
# 6             1.0       1.0            0         0          0
# 7             2.0       2.0            0         0          0
# 8             2.0       2.0            0         0          0
# 9             2.0       2.0            0         0          0
# 10            0.0       0.0            0         0          1
# 11            4.0       0.0            0         0          0
# 12            5.0       2.0            0         1          0
# 13            9.0       2.0            0         0          0
# 14            9.0       2.0            0         0          0
# 15            2.0       2.0            0         0          0
# 16            3.0       2.0            0         0          0
# 17            3.0       2.0            0         0          0
# 18            3.0       2.0            0         0          0
# 19            8.0       2.0            0         0          0
# 20            3.0       2.0            0         0          0
# 21            5.0       2.0            0         0          0
# 22            9.0       2.0            0         0          0
# 23            9.0       2.0            0         0          0
# 24            8.0       2.0            0         0          0
#
#     helpParticipate  helpAlert  result
# 0                 0          0       1
# 1                 0          0       1
# 2                 0          0       0
# 3                 0          0       0
# 4                 0          0       0
# 5                 0          0       1
# 6                 0          0       1
# 7                 0          0       0
# 8                 0          0       1
# 9                 0          0       0
# 10                0          0       1
# 11                1          0       1
# 12                0          0       0
# 13                0          0       1
# 14                0          0       0
# 15                0          0       1
# 16                0          0       1
# 17                0          0       0
# 18                0          0       0
# 19                0          0       0
# 20                0          0       1
# 21                0          1       1
# 22                0          1       1
# 23                0          1       0
# 24                0          0       0

# %% [markdown]
# ---
# # Training Model with Raw Data
# ---

# %%
from sklearn.model_selection import train_test_split

y_raw = df['result']
X_raw = df.drop(columns=['result'])

X_train_raw, X_test_raw, Y_train_raw, Y_test_raw = train_test_split(X_raw, y_raw, test_size = 0.2, random_state = 0)

# %% [markdown]
# ---
# # 1) Logistic Regression
# ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

LR_raw = LogisticRegression()
LR_raw.fit(X_train_raw, Y_train_raw)

predictions_LR_raw = LR_raw.predict(X_test_raw)
accuracy_LR_raw = accuracy_score(Y_test_raw, predictions_LR_raw)
print("Accuracy:", accuracy_LR_raw)

report_LR_raw = classification_report(Y_test_raw, predictions_LR_raw)
print("Classification Report:")
print(report_LR_raw)
# Out:
# Accuracy: 0.6
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.60         5
#    macro avg       0.58      0.58      0.58         5
# weighted avg       0.60      0.60      0.60         5

# %% [markdown]
# ---
# # 2) RandomForest Classifier
# ---

# %%
from sklearn.ensemble import RandomForestClassifier

clf_raw = RandomForestClassifier(n_estimators = 1000)
clf_raw.fit(X_train_raw, Y_train_raw)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred_LR_raw = clf_raw.predict(X_test_raw)
accuracy_LR_raw = clf_raw.score(X_test_raw, Y_test_raw)

report_LR_raw = classification_report(Y_test_raw, y_pred_LR_raw)
print("Accuracy:", accuracy_LR_raw)
print("Classification Report:")
print(report_LR_raw)
# Out:
# Accuracy: 0.8
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.80         5
#    macro avg       0.83      0.83      0.80         5
# weighted avg       0.87      0.80      0.80         5

# %%
import seaborn as sns

feature_importance_raw = clf_raw.feature_importances_
feature_df_raw = pd.DataFrame({'Features':X_train_raw.columns, 'Importances':feature_importance_raw})
sns.barplot(x = 'Importances', y = 'Features', data = feature_df_raw)
# Out:
# <Axes: xlabel='Importances', ylabel='Features'>

# %% [markdown]
# ---
# # CTGAN
# ---

# %%
# !pip install ctgan
# !pip install table_evaluator
# Out:
# Collecting ctgan
#   Downloading ctgan-0.9.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: tqdm>=4.15 in /usr/local/lib/python3.10/dist-packages (from ctgan) (4.66.2)
# Collecting rdt>=1.6.1 (from ctgan)
#   Downloading rdt-1.10.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.25.2)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.2.2)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.5.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan) (2.2.1+cu121)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->ctgan) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->ctgan) (2023.4)
# Collecting Faker<20,>=17 (from rdt>=1.6.1->ctgan)
#   Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from rdt>=1.6.1->ctgan) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.3->ctgan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.3->ctgan) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 42.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 53.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 60.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->ctgan)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->ctgan)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->ctgan) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->ctgan) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, Faker, rdt, nvidia-cusolver-cu12, ctgan
# Successfully installed Faker-19.13.0 ctgan-0.9.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 rdt-1.10.0
# Collecting table_evaluator
#   Downloading table_evaluator-1.6.1-py3-none-any.whl (22 kB)
# Collecting pandas==2.0.* (from table_evaluator)
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (5.9.5)
# Collecting dython==0.7.3 (from table_evaluator)
#   Downloading dython-0.7.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from table_evaluator) (1.11.4)
# Collecting scikit-plot>=0.3.7 (from dython==0.7.3->table_evaluator)
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.*->table_evaluator) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.*->table_evaluator) (2023.4)
# Collecting tzdata>=2022.1 (from pandas==2.0.*->table_evaluator)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->table_evaluator) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->table_evaluator) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->table_evaluator) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.*->table_evaluator) (1.16.0)
# Installing collected packages: tzdata, pandas, scikit-plot, dython, table_evaluator
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# Successfully installed dython-0.7.3 pandas-2.0.3 scikit-plot-0.3.7 table_evaluator-1.6.1 tzdata-2024.1

# %%
categorical_features = df.drop('result', axis=1).columns.tolist()

# %%
from ctgan import CTGAN

ctgan = CTGAN(verbose = True)
ctgan.fit((df), categorical_features, epochs = 4000)
# Out:
# Gen. (-0.65) | Discrim. (-0.62): 100%|██████████| 4000/4000 [18:14<00:00,  3.65it/s]

# %%
samples = ctgan.sample(2000)

# %%
samples
# Out:
#       disType  haksuNum  classNum  className  classDept  subjectArea  \
# 0         3.0      19.0         2        8.0       14.0          3.0
# 1         2.0       5.0         1       17.0       13.0          4.0
# 2         3.0       4.0         1        9.0        7.0          8.0
# 3         2.0      20.0         1       22.0       12.0          2.0
# 4         1.0      17.0         1        4.0        1.0          1.0
# ...       ...       ...       ...        ...        ...          ...
# 1995      0.0      12.0         1       23.0       14.0          2.0
# 1996      1.0      16.0         2        6.0       13.0          1.0
# 1997      0.0       9.0         3       10.0       14.0          2.0
# 1998      2.0       3.0         1       17.0       13.0          4.0
# 1999      2.0      20.0         1       22.0       12.0          2.0
#
#       subjectArea2  profName  studentNum  classTime  Credit  classDate  \
# 0              1.0      13.0         3.0        1.0     1.0       14.0
# 1              0.0      19.0         8.0        1.0     0.0        2.0
# 2              0.0       2.0         7.0        1.0     1.0       14.0
# 3              2.0       0.0         1.0        1.0     1.0       13.0
# 4              1.0      14.0         1.0        0.0     0.0       11.0
# ...            ...       ...         ...        ...     ...        ...
# 1995           2.0       8.0         9.0        1.0     1.0        4.0
# 1996           1.0       5.0         1.0        0.0     0.0        1.0
# 1997           2.0      12.0         9.0        1.0     1.0       13.0
# 1998           0.0      19.0         8.0        1.0     1.0        2.0
# 1999           2.0       0.0         1.0        1.0     1.0       13.0
#
#       classLocation  helpType  classOnline  helpMove  helpTeach  \
# 0               2.0       2.0            0         0          0
# 1               5.0       2.0            0         0          0
# 2               9.0       2.0            0         0          0
# 3               9.0       2.0            0         0          0
# 4               4.0       0.0            0         0          0
# ...             ...       ...          ...       ...        ...
# 1995            3.0       2.0            0         0          0
# 1996            8.0       2.0            0         1          0
# 1997            3.0       2.0            0         0          0
# 1998            5.0       2.0            0         0          0
# 1999            9.0       2.0            0         0          0
#
#       helpParticipate  helpAlert  result
# 0                   0          0       0
# 1                   0          1       1
# 2                   0          0       1
# 3                   0          1       0
# 4                   1          0       1
# ...               ...        ...     ...
# 1995                0          0       0
# 1996                0          0       0
# 1997                0          0       0
# 1998                0          0       1
# 1999                0          1       0
#
# [2000 rows x 20 columns]

# %% [markdown]
# # Original + CTGAN data

# %%
df_final = pd.concat([samples, df], axis = 0)

# %%
df_final
# Out:
#     disType  haksuNum  classNum  className  classDept  subjectArea  \
# 0       3.0      19.0         2        8.0       14.0          3.0
# 1       2.0       5.0         1       17.0       13.0          4.0
# 2       3.0       4.0         1        9.0        7.0          8.0
# 3       2.0      20.0         1       22.0       12.0          2.0
# 4       1.0      17.0         1        4.0        1.0          1.0
# ..      ...       ...       ...        ...        ...          ...
# 20      0.0      15.0         1       21.0       14.0          3.0
# 21      2.0       5.0         1       17.0       13.0          4.0
# 22      2.0      14.0         1       20.0        6.0          2.0
# 23      2.0      20.0         1       22.0       12.0          2.0
# 24      0.0       8.0         2       19.0        8.0          1.0
#
#     subjectArea2  profName  studentNum  classTime  Credit  classDate  \
# 0            1.0      13.0         3.0        1.0     1.0       14.0
# 1            0.0      19.0         8.0        1.0     0.0        2.0
# 2            0.0       2.0         7.0        1.0     1.0       14.0
# 3            2.0       0.0         1.0        1.0     1.0       13.0
# 4            1.0      14.0         1.0        0.0     0.0       11.0
# ..           ...       ...         ...        ...     ...        ...
# 20           3.0      16.0         6.0        1.0     1.0        6.0
# 21           0.0      19.0         8.0        1.0     1.0        2.0
# 22           2.0      23.0         5.0        1.0     1.0       16.0
# 23           2.0       0.0         1.0        1.0     1.0       13.0
# 24           1.0      21.0         3.0        1.0     1.0       13.0
#
#     classLocation  helpType  classOnline  helpMove  helpTeach  \
# 0             2.0       2.0            0         0          0
# 1             5.0       2.0            0         0          0
# 2             9.0       2.0            0         0          0
# 3             9.0       2.0            0         0          0
# 4             4.0       0.0            0         0          0
# ..            ...       ...          ...       ...        ...
# 20            3.0       2.0            0         0          0
# 21            5.0       2.0            0         0          0
# 22            9.0       2.0            0         0          0
# 23            9.0       2.0            0         0          0
# 24            8.0       2.0            0         0          0
#
#     helpParticipate  helpAlert  result
# 0                 0          0       0
# 1                 0          1       1
# 2                 0          0       1
# 3                 0          1       0
# 4                 1          0       1
# ..              ...        ...     ...
# 20                0          0       1
# 21                0          1       1
# 22                0          1       1
# 23                0          1       0
# 24                0          0       0
#
# [2025 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split

y = df_final['result']
X = df_final.drop(columns=['result'])

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ---
# # 1) Logistic Regresion
# ---

# %%
LR = LogisticRegression()
LR.fit(X_train, Y_train)

y_pred_LR = LR.predict(X_test)
accuracy_LR = accuracy_score(Y_test, y_pred_LR)
print("Accuracy:", accuracy_LR)

report_LR = classification_report(Y_test, y_pred_LR)
print("Classification Report:")
print(report_LR)
# Out:
# Accuracy: 0.8303747534516766
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       227
#            1       0.84      0.86      0.85       280
#
#     accuracy                           0.83       507
#    macro avg       0.83      0.83      0.83       507
# weighted avg       0.83      0.83      0.83       507
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ---
# # 2) RandomForest Classifier
# ---

# %%
clf = RandomForestClassifier(n_estimators = 1000)
clf.fit(X_train, Y_train)

y_pred_clf = clf.predict(X_test)
accuracy_clf = accuracy_score(Y_test, y_pred_clf)
print("Accuracy:", accuracy_clf)

report_clf = classification_report(Y_test, y_pred_clf)
print("Classification Report:")
print(report_clf)
# Out:
# Accuracy: 0.9408284023668639
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93       227
#            1       0.95      0.94      0.95       280
#
#     accuracy                           0.94       507
#    macro avg       0.94      0.94      0.94       507
# weighted avg       0.94      0.94      0.94       507

# %%
feature_importance = clf.feature_importances_
feature_df = pd.DataFrame({'Features':X_train.columns, 'Importances':feature_importance})
sns.barplot(x = 'Importances', y = 'Features', data = feature_df)
# Out:
# <Axes: xlabel='Importances', ylabel='Features'>

# %% [markdown]
# ---
# # 3) KNN
# ---

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, Y_train)

y_pred_knn = knn.predict(X_test)
accuracy_knn = accuracy_score(Y_test, y_pred_knn)

print("Accuracy:", accuracy_knn)
# Out:
# Accuracy: 0.883629191321499

# %% [markdown]
# ---
# # 4) DNN
# ---

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler

dnn = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

dnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history_dnn = dnn.fit(X_train, Y_train, epochs=100, batch_size=32, validation_data=(X_test, Y_test))

test_loss, test_accuracy = dnn.evaluate(X_test, Y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 48/48 [==============================] - 4s 15ms/step - loss: 1.2620 - accuracy: 0.5184 - val_loss: 0.6518 - val_accuracy: 0.6331
# Epoch 2/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.8505 - accuracy: 0.5270 - val_loss: 0.6582 - val_accuracy: 0.6529
# Epoch 3/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7369 - accuracy: 0.5402 - val_loss: 0.6557 - val_accuracy: 0.6765
# Epoch 4/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6858 - accuracy: 0.5705 - val_loss: 0.6331 - val_accuracy: 0.7357
# Epoch 5/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.6563 - accuracy: 0.6140 - val_loss: 0.6104 - val_accuracy: 0.7732
# Epoch 6/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.6356 - accuracy: 0.6212 - val_loss: 0.5903 - val_accuracy: 0.7219
# Epoch 7/100
# 48/48 [==============================] - 1s 20ms/step - loss: 0.6196 - accuracy: 0.6515 - val_loss: 0.5551 - val_accuracy: 0.7377
# Epoch 8/100
# 48/48 [==============================] - 1s 25ms/step - loss: 0.5893 - accuracy: 0.6937 - val_loss: 0.5162 - val_accuracy: 0.8028
# Epoch 9/100
# 48/48 [==============================] - 1s 18ms/step - loss: 0.5606 - accuracy: 0.7029 - val_loss: 0.4783 - val_accuracy: 0.8304
# Epoch 10/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.5504 - accuracy: 0.7286 - val_loss: 0.4729 - val_accuracy: 0.8442
# Epoch 11/100
# 48/48 [==============================] - 1s 21ms/step - loss: 0.5192 - accuracy: 0.7543 - val_loss: 0.4441 - val_accuracy: 0.8126
# Epoch 12/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.5171 - accuracy: 0.7602 - val_loss: 0.4283 - val_accuracy: 0.8284
# Epoch 13/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.4872 - accuracy: 0.7681 - val_loss: 0.4060 - val_accuracy: 0.8363
# Epoch 14/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.4835 - accuracy: 0.7925 - val_loss: 0.3894 - val_accuracy: 0.8600
# Epoch 15/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.4573 - accuracy: 0.7978 - val_loss: 0.3760 - val_accuracy: 0.8560
# Epoch 16/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.4714 - accuracy: 0.8037 - val_loss: 0.3770 - val_accuracy: 0.8619
# Epoch 17/100
# 48/48 [==============================] - 1s 13ms/step - loss: 0.4730 - accuracy: 0.8096 - val_loss: 0.3776 - val_accuracy: 0.8619
# Epoch 18/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.4511 - accuracy: 0.8136 - val_loss: 0.3613 - val_accuracy: 0.8600
# Epoch 19/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.4659 - accuracy: 0.8103 - val_loss: 0.3654 - val_accuracy: 0.8659
# Epoch 20/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.4352 - accuracy: 0.8307 - val_loss: 0.3537 - val_accuracy: 0.8679
# Epoch 21/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4219 - accuracy: 0.8281 - val_loss: 0.3443 - val_accuracy: 0.8659
# Epoch 22/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3986 - accuracy: 0.8366 - val_loss: 0.3412 - val_accuracy: 0.8639
# Epoch 23/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4071 - accuracy: 0.8419 - val_loss: 0.3349 - val_accuracy: 0.8679
# Epoch 24/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.4066 - accuracy: 0.8439 - val_loss: 0.3289 - val_accuracy: 0.8718
# Epoch 25/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3893 - accuracy: 0.8373 - val_loss: 0.3207 - val_accuracy: 0.8679
# Epoch 26/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.3782 - accuracy: 0.8465 - val_loss: 0.3182 - val_accuracy: 0.8698
# Epoch 27/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3851 - accuracy: 0.8524 - val_loss: 0.3158 - val_accuracy: 0.8738
# Epoch 28/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3753 - accuracy: 0.8557 - val_loss: 0.3115 - val_accuracy: 0.8698
# Epoch 29/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.3758 - accuracy: 0.8597 - val_loss: 0.3109 - val_accuracy: 0.8718
# Epoch 30/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.3783 - accuracy: 0.8557 - val_loss: 0.3122 - val_accuracy: 0.8659
# Epoch 31/100
# 48/48 [==============================] - 1s 20ms/step - loss: 0.3748 - accuracy: 0.8531 - val_loss: 0.3022 - val_accuracy: 0.8679
# Epoch 32/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.3823 - accuracy: 0.8491 - val_loss: 0.3089 - val_accuracy: 0.8698
# Epoch 33/100
# 48/48 [==============================] - 1s 22ms/step - loss: 0.3648 - accuracy: 0.8590 - val_loss: 0.2970 - val_accuracy: 0.8718
# Epoch 34/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.3415 - accuracy: 0.8735 - val_loss: 0.2851 - val_accuracy: 0.8974
# Epoch 35/100
# 48/48 [==============================] - 1s 18ms/step - loss: 0.3523 - accuracy: 0.8630 - val_loss: 0.2952 - val_accuracy: 0.8698
# Epoch 36/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.3458 - accuracy: 0.8663 - val_loss: 0.2885 - val_accuracy: 0.8915
# Epoch 37/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.3660 - accuracy: 0.8676 - val_loss: 0.2934 - val_accuracy: 0.8994
# Epoch 38/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.3479 - accuracy: 0.8538 - val_loss: 0.2832 - val_accuracy: 0.8856
# Epoch 39/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.3452 - accuracy: 0.8630 - val_loss: 0.2948 - val_accuracy: 0.8895
# Epoch 40/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.3419 - accuracy: 0.8689 - val_loss: 0.2839 - val_accuracy: 0.8895
# Epoch 41/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.3259 - accuracy: 0.8676 - val_loss: 0.2865 - val_accuracy: 0.8915
# Epoch 42/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.3429 - accuracy: 0.8689 - val_loss: 0.2740 - val_accuracy: 0.8994
# Epoch 43/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3296 - accuracy: 0.8689 - val_loss: 0.2855 - val_accuracy: 0.8955
# Epoch 44/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3177 - accuracy: 0.8860 - val_loss: 0.2724 - val_accuracy: 0.8955
# Epoch 45/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.3058 - accuracy: 0.8827 - val_loss: 0.2689 - val_accuracy: 0.9053
# Epoch 46/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2974 - accuracy: 0.8887 - val_loss: 0.2747 - val_accuracy: 0.8876
# Epoch 47/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.3225 - accuracy: 0.8742 - val_loss: 0.2668 - val_accuracy: 0.8994
# Epoch 48/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3262 - accuracy: 0.8762 - val_loss: 0.2663 - val_accuracy: 0.9034
# Epoch 49/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.3191 - accuracy: 0.8748 - val_loss: 0.2751 - val_accuracy: 0.8935
# Epoch 50/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3100 - accuracy: 0.8854 - val_loss: 0.2737 - val_accuracy: 0.8935
# Epoch 51/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3057 - accuracy: 0.8847 - val_loss: 0.2774 - val_accuracy: 0.8935
# Epoch 52/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.3058 - accuracy: 0.8953 - val_loss: 0.2712 - val_accuracy: 0.8994
# Epoch 53/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.3028 - accuracy: 0.8854 - val_loss: 0.2691 - val_accuracy: 0.8955
# Epoch 54/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2933 - accuracy: 0.8841 - val_loss: 0.2673 - val_accuracy: 0.8935
# Epoch 55/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3117 - accuracy: 0.8788 - val_loss: 0.2685 - val_accuracy: 0.9014
# Epoch 56/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.3015 - accuracy: 0.8880 - val_loss: 0.2693 - val_accuracy: 0.8935
# Epoch 57/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2960 - accuracy: 0.8933 - val_loss: 0.2623 - val_accuracy: 0.9034
# Epoch 58/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.3030 - accuracy: 0.8880 - val_loss: 0.2628 - val_accuracy: 0.9093
# Epoch 59/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2739 - accuracy: 0.8959 - val_loss: 0.2696 - val_accuracy: 0.8915
# Epoch 60/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2991 - accuracy: 0.8906 - val_loss: 0.2599 - val_accuracy: 0.9152
# Epoch 61/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2800 - accuracy: 0.8874 - val_loss: 0.2632 - val_accuracy: 0.9034
# Epoch 62/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2875 - accuracy: 0.8880 - val_loss: 0.2630 - val_accuracy: 0.9014
# Epoch 63/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2886 - accuracy: 0.8939 - val_loss: 0.2663 - val_accuracy: 0.9034
# Epoch 64/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2817 - accuracy: 0.8953 - val_loss: 0.2632 - val_accuracy: 0.8974
# Epoch 65/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2791 - accuracy: 0.9018 - val_loss: 0.2573 - val_accuracy: 0.9034
# Epoch 66/100
# 48/48 [==============================] - 1s 24ms/step - loss: 0.2970 - accuracy: 0.8814 - val_loss: 0.2650 - val_accuracy: 0.8994
# Epoch 67/100
# 48/48 [==============================] - 1s 23ms/step - loss: 0.2728 - accuracy: 0.8913 - val_loss: 0.2654 - val_accuracy: 0.8994
# Epoch 68/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.2781 - accuracy: 0.8933 - val_loss: 0.2618 - val_accuracy: 0.9053
# Epoch 69/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2920 - accuracy: 0.8946 - val_loss: 0.2624 - val_accuracy: 0.9073
# Epoch 70/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.2903 - accuracy: 0.8939 - val_loss: 0.2622 - val_accuracy: 0.9034
# Epoch 71/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2958 - accuracy: 0.8867 - val_loss: 0.2600 - val_accuracy: 0.9034
# Epoch 72/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2640 - accuracy: 0.8979 - val_loss: 0.2572 - val_accuracy: 0.8974
# Epoch 73/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2670 - accuracy: 0.8972 - val_loss: 0.2599 - val_accuracy: 0.9034
# Epoch 74/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.2688 - accuracy: 0.9012 - val_loss: 0.2558 - val_accuracy: 0.9053
# Epoch 75/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.2815 - accuracy: 0.8972 - val_loss: 0.2641 - val_accuracy: 0.8994
# Epoch 76/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.2589 - accuracy: 0.9025 - val_loss: 0.2810 - val_accuracy: 0.8955
# Epoch 77/100
# 48/48 [==============================] - 1s 11ms/step - loss: 0.2574 - accuracy: 0.9065 - val_loss: 0.2657 - val_accuracy: 0.8994
# Epoch 78/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.2649 - accuracy: 0.8992 - val_loss: 0.2636 - val_accuracy: 0.9034
# Epoch 79/100
# 48/48 [==============================] - 1s 18ms/step - loss: 0.2717 - accuracy: 0.9032 - val_loss: 0.2655 - val_accuracy: 0.9053
# Epoch 80/100
# 48/48 [==============================] - 1s 14ms/step - loss: 0.2683 - accuracy: 0.8992 - val_loss: 0.2620 - val_accuracy: 0.9053
# Epoch 81/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.2773 - accuracy: 0.8999 - val_loss: 0.2656 - val_accuracy: 0.9034
# Epoch 82/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.2687 - accuracy: 0.8986 - val_loss: 0.2743 - val_accuracy: 0.8974
# Epoch 83/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.2672 - accuracy: 0.9025 - val_loss: 0.2666 - val_accuracy: 0.8935
# Epoch 84/100
# 48/48 [==============================] - 1s 14ms/step - loss: 0.2743 - accuracy: 0.9032 - val_loss: 0.2535 - val_accuracy: 0.9073
# Epoch 85/100
# 48/48 [==============================] - 1s 20ms/step - loss: 0.2739 - accuracy: 0.8999 - val_loss: 0.2536 - val_accuracy: 0.9034
# Epoch 86/100
# 48/48 [==============================] - 1s 27ms/step - loss: 0.2569 - accuracy: 0.9065 - val_loss: 0.2688 - val_accuracy: 0.9014
# Epoch 87/100
# 48/48 [==============================] - 1s 26ms/step - loss: 0.2587 - accuracy: 0.9012 - val_loss: 0.2756 - val_accuracy: 0.9014
# Epoch 88/100
# 48/48 [==============================] - 1s 27ms/step - loss: 0.2674 - accuracy: 0.8992 - val_loss: 0.2640 - val_accuracy: 0.9034
# Epoch 89/100
# 48/48 [==============================] - 1s 25ms/step - loss: 0.2756 - accuracy: 0.8926 - val_loss: 0.2568 - val_accuracy: 0.9034
# Epoch 90/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.2713 - accuracy: 0.9005 - val_loss: 0.2601 - val_accuracy: 0.9073
# Epoch 91/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.2563 - accuracy: 0.9018 - val_loss: 0.2655 - val_accuracy: 0.8994
# Epoch 92/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.2460 - accuracy: 0.9025 - val_loss: 0.2699 - val_accuracy: 0.8994
# Epoch 93/100
# 48/48 [==============================] - 1s 15ms/step - loss: 0.2529 - accuracy: 0.9084 - val_loss: 0.2762 - val_accuracy: 0.8935
# Epoch 94/100
# 48/48 [==============================] - 1s 21ms/step - loss: 0.2524 - accuracy: 0.9097 - val_loss: 0.2631 - val_accuracy: 0.9034
# Epoch 95/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.2537 - accuracy: 0.9084 - val_loss: 0.2782 - val_accuracy: 0.8974
# Epoch 96/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.2564 - accuracy: 0.9025 - val_loss: 0.2688 - val_accuracy: 0.8994
# Epoch 97/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.2501 - accuracy: 0.9018 - val_loss: 0.2642 - val_accuracy: 0.9093
# Epoch 98/100
# 48/48 [==============================] - 1s 17ms/step - loss: 0.2541 - accuracy: 0.9012 - val_loss: 0.2676 - val_accuracy: 0.9034
# Epoch 99/100
# 48/48 [==============================] - 1s 12ms/step - loss: 0.2515 - accuracy: 0.9012 - val_loss: 0.2681 - val_accuracy: 0.8994
# Epoch 100/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.2649 - accuracy: 0.9032 - val_loss: 0.2632 - val_accuracy: 0.9053
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.9053
# Test Accuracy: 0.9053254723548889

# %% [markdown]
# ---
# # 5) XGBoost
# ---

# %%
import xgboost as xgb_model
dtrain_xgb = xgb_model.DMatrix(X_train, label = Y_train)

params_xgb = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'eta': 0.1,
    'max_depth': 100
}

xgb = xgb_model.train(params_xgb, dtrain_xgb)

dtest_xgb = xgb_model.DMatrix(X_test)

y_pred_xgb = xgb.predict(dtest_xgb)

y_pred_binary_xgb = [1 if p >= 0.5 else 0 for p in y_pred_xgb]

accuracy_xgb = accuracy_score(Y_test, y_pred_binary_xgb)
print("Accuracy:", accuracy_xgb)
# Out:
# Accuracy: 0.9151873767258383

# %% [markdown]
# ---
# # 6) Bagging Classifier
# ---

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

base_classifier = DecisionTreeClassifier(random_state=42)
bclf = BaggingClassifier(base_classifier, n_estimators=100, random_state=42)
bclf.fit(X_train, Y_train)

y_pred_bclf = bclf.predict(X_test)

accuracy_bclf = accuracy_score(Y_test, y_pred_bclf)
print("Accuracy", accuracy_bclf)
# Out:
# Accuracy 0.9289940828402367

# %% [markdown]
# ---
# # Best Classifier -  ROC/AUC
# ---

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have your models lr, clf, knn, xgb, bclf
# Assuming you have your test data: X_test, y_test
# Get the predicted probabilities for each model

LR_probs = LR.predict_proba(X_test)[:, 1]
clf_probs = clf.predict_proba(X_test)[:, 1]
knn_probs = knn.predict_proba(X_test)[:, 1]
dnn_probs = dnn.predict(X_test)
xgb_probs = xgb.predict(dtest_xgb)
xgb_probs = xgb_probs / (1 + xgb_probs)
bclf_probs = bclf.predict_proba(X_test)[:, 1]

# Calculate ROC curve and AUC for each model
lr_fpr, lr_tpr, _ = roc_curve(Y_test, LR_probs)
lr_auc = auc(lr_fpr, lr_tpr)

clf_fpr, clf_tpr, _ = roc_curve(Y_test, clf_probs)
clf_auc = auc(clf_fpr, clf_tpr)

knn_fpr, knn_tpr, _ = roc_curve(Y_test, knn_probs)
knn_auc = auc(knn_fpr, knn_tpr)

dnn_fpr, dnn_tpr, _ = roc_curve(Y_test, dnn_probs)
dnn_auc = auc(dnn_fpr, dnn_tpr)

xgb_fpr, xgb_tpr, _ = roc_curve(Y_test, xgb_probs)
xgb_auc = auc(xgb_fpr, xgb_tpr)

bclf_fpr, bclf_tpr, _ = roc_curve(Y_test, bclf_probs)
bclf_auc = auc(bclf_fpr, bclf_tpr)

# Plot ROC curves
plt.figure(figsize=(10, 7))
plt.plot(lr_fpr, lr_tpr, linestyle='-', label=f'LR (AUC = {lr_auc:.2f})')
plt.plot(clf_fpr, clf_tpr, linestyle='-', label=f'CLF (AUC = {clf_auc:.2f})')
plt.plot(knn_fpr, knn_tpr, linestyle='-', label=f'KNN (AUC = {knn_auc:.2f})')
plt.plot(dnn_fpr, dnn_tpr, linestyle='-', label=f'DNN (AUC = {dnn_auc:.2f})')
plt.plot(xgb_fpr, xgb_tpr, linestyle='-', label=f'XGB (AUC = {xgb_auc:.2f})')
plt.plot(bclf_fpr, bclf_tpr, linestyle='-', label=f'BCLF (AUC = {bclf_auc:.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt

LR_probs = LR.predict_proba(X_test)[:, 1]
clf_probs = clf.predict_proba(X_test)[:, 1]
knn_probs = knn.predict_proba(X_test)[:, 1]
dnn_probs = dnn.predict(X_test)
xgb_probs = xgb.predict(dtest_xgb)
xgb_probs = xgb_probs / (1 + xgb_probs)
bclf_probs = bclf.predict_proba(X_test)[:, 1]

# Calculate precision-recall curve and AUC for each model
LR_precision, LR_recall, _ = precision_recall_curve(Y_test, LR_probs)
lr_pr_auc = auc(LR_recall, LR_precision)

clf_precision, clf_recall, _ = precision_recall_curve(Y_test, clf_probs)
clf_pr_auc = auc(clf_recall, clf_precision)

knn_precision, knn_recall, _ = precision_recall_curve(Y_test, knn_probs)
knn_pr_auc = auc(knn_recall, knn_precision)

dnn_precision, dnn_recall, _ = precision_recall_curve(Y_test, dnn_probs)
dnn_pr_auc = auc(dnn_recall, dnn_precision)

xgb_precision, xgb_recall, _ = precision_recall_curve(Y_test, xgb_probs)
xgb_pr_auc = auc(xgb_recall, xgb_precision)

bclf_precision, bclf_recall, _ = precision_recall_curve(Y_test, bclf_probs)
bclf_pr_auc = auc(bclf_recall, bclf_precision)

# Plot Precision-Recall curves
plt.figure(figsize=(10, 7))
plt.plot(LR_recall, LR_precision, linestyle='-', label=f'LR (AUC = {lr_pr_auc:.2f})')
plt.plot(clf_recall, clf_precision, linestyle='-', label=f'CLF (AUC = {clf_pr_auc:.2f})')
plt.plot(knn_recall, knn_precision, linestyle='-', label=f'KNN (AUC = {knn_pr_auc:.2f})')
plt.plot(dnn_recall, dnn_precision, linestyle='-', label=f'DNN (AUC = {dnn_pr_auc:.2f})')
plt.plot(xgb_recall, xgb_precision, linestyle='-', label=f'XGB (AUC = {xgb_pr_auc:.2f})')
plt.plot(bclf_recall, bclf_precision, linestyle='-', label=f'BCLF (AUC = {bclf_pr_auc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# ---
# # 실제 모델 사용
# ---

# %%
testing_file_path = '/content/drive/MyDrive/Ewhathon_test_sample.xlsx'
sample_df = pd.read_excel(testing_file_path)

# %%
sample_df
# Out:
#   장애유형   학수번호  분반           교과목명  개설학과/전공         교과영역 교과목 구분  교수명   정원  시간  \
# 0   시각  38640   2        북한과인권문제      북한학           전선     전선  박민주  100   3
# 1   청각  11148   2    문학으로보는사랑의역사  이화인문과학원  핵심교양(문학과언어)     교양  김경미   80   3
# 2   시각  36500   1        디지털논리설계    컴퓨터공학           전선     전선  박상수   50   3
# 3  뇌병변  35339   1      객체지향프로그래밍    컴퓨터공학           전기     전기  안영아   35   3
# 4   청각  34947   2       교육철학및교육사     교육학과           전기     전기  이은주   30   2
# 5  뇌병변  20007   1           교육심리     교육학과           전기     전기  이승은   30   2
# 6  자폐성  20477   4           운영체제    컴퓨터공학           전필     전필  권진욱  110   3
# 7  자폐성  34743   3         정보통신공학    컴퓨터공학           전필     전필  이형준   70   3
# 8   시각  11233   2  음악테크놀로지와프로그래밍      작곡과    컴퓨팅과수리적사고     교양  전현석   90   3
#
#    학점         요일/교시  교실   지원종류 원격강의 이동지원 교생실습지원 수업참여지원 알림사항지원
# 0   3  화 4~4\n금 5~5   포  노트북속타    X    O      X      X      X
# 1   3  월 5~5\n수 4~4   학  노트북속타    X    X      X      O      O
# 2   3  월 3~3\n수 2~2  공A   노트필기    X    X      X      O      X
# 3   3  화 3~3\n목 2~2  공A   노트필기    X    O      X      X      X
# 4   2         화 2~3   교     기타    X    X      X      O      X
# 5   2         수 4~5   학   노트필기    X    O      X      X      O
# 6   3  월 6~6\n수 5~5  공A   노트필기    X    X      X      X      O
# 7   3  월 3~3\n수 2~2  공B   노트필기    X    X      X      X      O
# 8   3  수 3~3\n금 4~4   음   노트필기    X    X      X      X      O

# %%
def encode_dataframe(df):
    df = df.rename(columns={'장애유형': 'disType',
                            '학수번호': 'haksuNum',
                            '분반': 'classNum',
                            '교과목명': 'className',
                            '개설학과/전공': 'classDept',
                            '교과영역': 'subjectArea',
                            '교과목 구분': 'subjectArea2',
                            '교수명': 'profName',
                            '정원': 'studentNum',
                            '시간': 'classTime',
                            '학점': 'Credit',
                            '요일/교시': 'classDate',
                            '교실': 'classLocation',
                            '지원종류': 'helpType',
                            '원격강의': 'classOnline',
                            '이동지원': 'helpMove',
                            '교생실습지원': 'helpTeach',
                            '수업참여지원': 'helpParticipate',
                            '알림사항지원': 'helpAlert'})

    df['disType'] = ordinal_encoder_disType.fit_transform(df[['disType']])
    df['haksuNum'] = ordinal_encoder_haksuNum.fit_transform(df[['haksuNum']])
    df['className'] = ordinal_encoder_className.fit_transform(df[['className']])
    df['classDept'] = ordinal_encoder_classDept.fit_transform(df[['classDept']])
    df['subjectArea'] = ordinal_encoder_subjectArea.fit_transform(df[['subjectArea']])
    df['subjectArea2'] = ordinal_encoder_subjectArea2.fit_transform(df[['subjectArea2']])
    df['profName'] = ordinal_encoder_profName.fit_transform(df[['profName']])
    df['studentNum'] = ordinal_encoder_studentNum.fit_transform(df[['studentNum']])
    df['classTime'] = ordinal_encoder_classTime.fit_transform(df[['classTime']])
    df['Credit'] = ordinal_encoder_Credit.fit_transform(df[['Credit']])
    df['classDate'] = ordinal_encoder_classDate.fit_transform(df[['classDate']])
    df['classLocation'] = ordinal_encoder_classLocation.fit_transform(df[['classLocation']])
    df['helpType'] = ordinal_encoder_helpType.fit_transform(df[['helpType']])
    df['classOnline'] = df['classOnline'].replace(replacement_map)
    df['helpMove'] = df['helpMove'].replace(replacement_map)
    df['helpTeach'] = df['helpTeach'].replace(replacement_map)
    df['helpParticipate'] = df['helpParticipate'].replace(replacement_map)
    df['helpAlert'] = df['helpAlert'].replace(replacement_map)

    return df

testing_df = encode_dataframe(sample_df)

# %%
print(testing_df)
# Out:
#    disType  haksuNum  classNum  className  classDept  subjectArea  \
# 0      1.0       8.0         2        5.0        1.0          1.0
# 1      3.0       0.0         2        4.0        2.0          4.0
# 2      1.0       7.0         1        3.0        4.0          1.0
# 3      0.0       6.0         1        0.0        4.0          0.0
# 4      3.0       5.0         2        2.0        0.0          0.0
# 5      0.0       2.0         1        1.0        0.0          0.0
# 6      2.0       3.0         4        6.0        4.0          2.0
# 7      2.0       4.0         3        8.0        4.0          2.0
# 8      1.0       1.0         2        7.0        3.0          3.0
#
#    subjectArea2  profName  studentNum  classTime  Credit  classDate  \
# 0           2.0       2.0         6.0        1.0     1.0        7.0
# 1           0.0       1.0         4.0        1.0     1.0        3.0
# 2           2.0       3.0         2.0        1.0     1.0        2.0
# 3           1.0       4.0         1.0        1.0     1.0        6.0
# 4           1.0       6.0         0.0        0.0     0.0        5.0
# 5           1.0       5.0         0.0        0.0     0.0        1.0
# 6           3.0       0.0         7.0        1.0     1.0        4.0
# 7           3.0       7.0         3.0        1.0     1.0        2.0
# 8           0.0       8.0         5.0        1.0     1.0        0.0
#
#    classLocation  helpType  classOnline  helpMove  helpTeach  helpParticipate  \
# 0            4.0       1.0            0         1          0                0
# 1            5.0       1.0            0         0          0                1
# 2            0.0       2.0            0         0          0                1
# 3            0.0       2.0            0         1          0                0
# 4            2.0       0.0            0         0          0                1
# 5            5.0       2.0            0         1          0                0
# 6            0.0       2.0            0         0          0                0
# 7            1.0       2.0            0         0          0                0
# 8            3.0       2.0            0         0          0                0
#
#    helpAlert
# 0          0
# 1          1
# 2          0
# 3          0
# 4          0
# 5          1
# 6          1
# 7          1
# 8          1

# %%
# Get predicted labels
y_pred_testing = clf.predict(testing_df)

# Get probabilities of being labeled as 1
y_pred_prob = clf.predict_proba(testing_df)
probability_of_label_1 = y_pred_prob[:, 1]

# Combine data points with their probabilities
data_with_probabilities = zip(testing_df.values, probability_of_label_1)

# Sort based on probabilities in ascending order (from least to highest)
sorted_data_with_probabilities = sorted(data_with_probabilities, key=lambda x: x[1])

# Get the original indices of the sorted data points
original_indices = sorted(range(len(probability_of_label_1)), key=lambda i: probability_of_label_1[i])

print("[매칭 성공 확률이 낮은 순으로 정렬]")
print()

for idx, (data, probability) in enumerate(sorted_data_with_probabilities):
    original_idx = original_indices[idx]
    print("**매칭 성공 확률:", probability, "%")
    print("학생 index:", original_idx)

    # Get the row corresponding to the original index
    row_data = sample_df.iloc[original_idx]
    print("학생 정보:")
    print(row_data)
    print()
# Out:
# [매칭 성공 확률이 낮은 순으로 정렬]
#
# **매칭 성공 확률: 0.39207229437229424 %
# 학생 index: 5
# 학생 정보:
# 장애유형         뇌병변
# 학수번호       20007
# 분반             1
# 교과목명        교육심리
# 개설학과/전공     교육학과
# 교과영역          전기
# 교과목 구분        전기
# 교수명          이승은
# 정원            30
# 시간             2
# 학점             2
# 요일/교시      수 4~5
# 교실             학
# 지원종류        노트필기
# 원격강의           X
# 이동지원           O
# 교생실습지원         X
# 수업참여지원         X
# 알림사항지원         O
# Name: 5, dtype: object
#
# **매칭 성공 확률: 0.4655 %
# 학생 index: 0
# 학생 정보:
# 장애유형                 시각
# 학수번호              38640
# 분반                    2
# 교과목명            북한과인권문제
# 개설학과/전공             북한학
# 교과영역                 전선
# 교과목 구분               전선
# 교수명                 박민주
# 정원                  100
# 시간                    3
# 학점                    3
# 요일/교시      화 4~4\n금 5~5
# 교실                    포
# 지원종류              노트북속타
# 원격강의                  X
# 이동지원                  O
# 교생실습지원                X
# 수업참여지원                X
# 알림사항지원                X
# Name: 0, dtype: object
#
# **매칭 성공 확률: 0.4860162698412698 %
# 학생 index: 3
# 학생 정보:
# 장애유형                뇌병변
# 학수번호              35339
# 분반                    1
# 교과목명          객체지향프로그래밍
# 개설학과/전공           컴퓨터공학
# 교과영역                 전기
# 교과목 구분               전기
# 교수명                 안영아
# 정원                   35
# 시간                    3
# 학점                    3
# 요일/교시      화 3~3\n목 2~2
# 교실                   공A
# 지원종류               노트필기
# 원격강의                  X
# 이동지원                  O
# 교생실습지원                X
# 수업참여지원                X
# 알림사항지원                X
# Name: 3, dtype: object
#
# **매칭 성공 확률: 0.6503333333333332 %
# 학생 index: 1
# 학생 정보:
# 장애유형                 청각
# 학수번호              11148
# 분반                    2
# 교과목명        문학으로보는사랑의역사
# 개설학과/전공         이화인문과학원
# 교과영역        핵심교양(문학과언어)
# 교과목 구분               교양
# 교수명                 김경미
# 정원                   80
# 시간                    3
# 학점                    3
# 요일/교시      월 5~5\n수 4~4
# 교실                    학
# 지원종류              노트북속타
# 원격강의                  X
# 이동지원                  X
# 교생실습지원                X
# 수업참여지원                O
# 알림사항지원                O
# Name: 1, dtype: object
#
# **매칭 성공 확률: 0.6583333333333332 %
# 학생 index: 7
# 학생 정보:
# 장애유형                자폐성
# 학수번호              34743
# 분반                    3
# 교과목명             정보통신공학
# 개설학과/전공           컴퓨터공학
# 교과영역                 전필
# 교과목 구분               전필
# 교수명                 이형준
# 정원                   70
# 시간                    3
# 학점                    3
# 요일/교시      월 3~3\n수 2~2
# 교실                   공B
# 지원종류               노트필기
# 원격강의                  X
# 이동지원                  X
# 교생실습지원                X
# 수업참여지원                X
# 알림사항지원                O
# Name: 7, dtype: object
#
# **매칭 성공 확률: 0.6587286467274334 %
# 학생 index: 8
# 학생 정보:
# 장애유형                  시각
# 학수번호               11233
# 분반                     2
# 교과목명       음악테크놀로지와프로그래밍
# 개설학과/전공              작곡과
# 교과영역           컴퓨팅과수리적사고
# 교과목 구분                교양
# 교수명                  전현석
# 정원                    90
# 시간                     3
# 학점                     3
# 요일/교시       수 3~3\n금 4~4
# 교실                     음
# 지원종류                노트필기
# 원격강의                   X
# 이동지원                   X
# 교생실습지원                 X
# 수업참여지원                 X
# 알림사항지원                 O
# Name: 8, dtype: object
#
# **매칭 성공 확률: 0.6686333333333332 %
# 학생 index: 2
# 학생 정보:
# 장애유형                 시각
# 학수번호              36500
# 분반                    1
# 교과목명            디지털논리설계
# 개설학과/전공           컴퓨터공학
# 교과영역                 전선
# 교과목 구분               전선
# 교수명                 박상수
# 정원                   50
# 시간                    3
# 학점                    3
# 요일/교시      월 3~3\n수 2~2
# 교실                   공A
# 지원종류               노트필기
# 원격강의                  X
# 이동지원                  X
# 교생실습지원                X
# 수업참여지원                O
# 알림사항지원                X
# Name: 2, dtype: object
#
# **매칭 성공 확률: 0.7013333333333334 %
# 학생 index: 6
# 학생 정보:
# 장애유형                자폐성
# 학수번호              20477
# 분반                    4
# 교과목명               운영체제
# 개설학과/전공           컴퓨터공학
# 교과영역                 전필
# 교과목 구분               전필
# 교수명                 권진욱
# 정원                  110
# 시간                    3
# 학점                    3
# 요일/교시      월 6~6\n수 5~5
# 교실                   공A
# 지원종류               노트필기
# 원격강의                  X
# 이동지원                  X
# 교생실습지원                X
# 수업참여지원                X
# 알림사항지원                O
# Name: 6, dtype: object
#
# **매칭 성공 확률: 0.728263492063492 %
# 학생 index: 4
# 학생 정보:
# 장애유형             청각
# 학수번호          34947
# 분반                2
# 교과목명       교육철학및교육사
# 개설학과/전공        교육학과
# 교과영역             전기
# 교과목 구분           전기
# 교수명             이은주
# 정원               30
# 시간                2
# 학점                2
# 요일/교시         화 2~3
# 교실                교
# 지원종류             기타
# 원격강의              X
# 이동지원              X
# 교생실습지원            X
# 수업참여지원            O
# 알림사항지원            X
# Name: 4, dtype: object
